# %%
import requests
import time

# Define your API Key
API_KEY = "3005c28e-15ba-48c1-b23b-b8cfd7490048"
API_KEY_ALT = "e6985657-408e-47b8-9fc7-1af457c89422"  # Assuming you have multiple keys

# List of URLs to fetch data from
urls = [
    # URLs with the main API_KEY
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Elon Musk\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Space Exploration\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Electric Vehicles\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Technology Trends\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Artificial Intelligence\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Space Exploration\" OR \"NASA\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Tesla Stock\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Launch\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Clean Energy\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Missions\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Cryptocurrency Trends\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Innovative Technologies\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Space Exploration\" OR \"Mars\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Autonomous Vehicles\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Artificial Intelligence\" OR \"Machine Learning\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Renewable Energy\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Innovations\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Tesla Innovations\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Funding\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Achievements\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&topic=Social Issues",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Artificial Intelligence\" OR \"Machine Learning\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Climate Change\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Healthcare Innovations\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Blockchain Technology\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Virtual Reality\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Digital Transformation\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Remote Work Trends\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"E-commerce Growth\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Cybersecurity Threats\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Renewable Energy\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Space Exploration\" OR \"NASA\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Cryptocurrency Trends\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Future of Work\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Sustainable Development Goals\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Artificial Intelligence Ethics\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Financial Technology\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Smart Cities\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Biotechnology Innovations\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Telemedicine Trends\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Space Tourism\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"5G Technology\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Genetic Engineering\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Green Technology\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Future Mobility\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Internet of Things\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Data Privacy\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Green Energy Solutions\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"SpaceX Innovations\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Quantum Computing\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    f"https://api.goperigon.com/v1/all?from=2024-04-03&q=\"Climate Action\"&sourceGroup=top100&language=en&apiKey={API_KEY}",
    
    # URLs with the alternate API_KEY_ALT
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=best-selling books 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=top movie releases 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=upcoming video games 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=top music albums 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=latest fashion trends 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=new technology gadgets 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=popular travel destinations 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=health and fitness tips 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=celebrity gossip news 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=latest food recipes 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=fitness equipment reviews 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=upcoming fashion shows 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=latest automotive trends 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=home decor ideas 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=parenting tips and advice 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=wedding planning tips 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=DIY craft ideas 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=latest tech startups 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=pet care tips 2024",
    f"https://api.goperigon.com/v1/all?apiKey={API_KEY_ALT}&q=financial investment trends 2024",
]

all_articles = []
total_articles = 0

def fetch_articles(url):
    global total_articles
    response = requests.get(url)
    if response.status_code == 200:
        articles = response.json().get("articles", [])
        total_articles += len(articles)
        for article in articles:
            all_articles.append({
                'articleID': article.get('articleId'),
                'title': article['title'],
                'description': article.get('description'),
                'content': article.get('content'),
                'publishedDate': article.get('pubDate'),
                'url': article['url'],
                'sourceDomain': article.get('source', {}).get('domain', 'N/A')  # Default to 'N/A' if 'source' or 'domain' is missing
            })
    else:
        print(f"Failed to fetch articles from {url}, HTTP Status Code: {response.status_code}")

for url in urls:
    time.sleep(1)
    fetch_articles(url)

# Print total number of articles collected
print(f"Total number of articles collected: {total_articles}")

# Print sample data to verify
if all_articles:
    print(all_articles[:2])  # Print the first two articles for verification
# Out:
# %3|1714785654.777|FAIL|rdkafka#producer-53| [thrd:mlk-scs-fvfgj4jmq6lr.attlocal.net:9092/0]: 10.251.53.252:9092/0: Connect to ipv4#10.251.53.252:9092 failed: Connection refused (after 2ms in state CONNECT)
# %3|1714785655.707|FAIL|rdkafka#producer-53| [thrd:mlk-scs-fvfgj4jmq6lr.attlocal.net:9092/0]: 10.251.53.252:9092/0: Connect to ipv4#10.251.53.252:9092 failed: Connection refused (after 1ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1714785658.718|FAIL|rdkafka#producer-53| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv6#[::1]:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1714785659.717|FAIL|rdkafka#producer-53| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# ...

# %%
# Producer Code

from confluent_kafka import Producer
import json

# Function to send data to Kafka topic
def send_to_kafka(topic, data):
    producer = Producer({'bootstrap.servers': 'localhost:9092'})  # Adjust Kafka broker address as needed
    for entry in data:
        producer.produce(topic, json.dumps(entry).encode('utf-8'))
    producer.flush()

# Main function
def main():

    # Define Kafka topic
    # kafka_topic = "Big_Data_Project_LSH"  # Adjust Kafka topic name as needed
    kafka_topic = "LSH_New_8"
    # Send data to Kafka topic
    send_to_kafka(kafka_topic, all_articles)

if __name__ == "__main__":
    main()

# %%
def scrape_article_content(article_url):
    try:
        response = requests.get(article_url)
        response.raise_for_status()  # Raise an exception for HTTP errors
        soup = BeautifulSoup(response.text, 'lxml')
        
        # Find the article body - Adjust this selector according to the site's layout
        # This is a generic selector; you need to customize it for the websites you are scraping
        article_body = soup.find('article')
        if article_body:
            return ' '.join([p.get_text(strip=True) for p in article_body.find_all('p')])
        else:
            return "Article body not found."
    except requests.RequestException as e:
        return f"Failed to retrieve article from {article_url}. Error: {e}"

import uuid

def generate_random_id():
    # Generate a random UUID
    random_id = uuid.uuid4()
    # Convert to a string without hyphens
    random_id_str = str(random_id).replace("-", "")
    return random_id_str

import requests
from bs4 import BeautifulSoup
import time

# Your NewsAPI key
API_KEY = 'df7132d10d34451fa7a40adb7f8016a1'  # Replace with your actual API key

# List of countries to fetch headlines from
countries = ['us', 'gb', 'ca', 'in', 'jp', 'it']

# NewsAPI endpoint for top headlines
url = 'https://newsapi.org/v2/top-headlines'

# %%
import requests
import time
import lxml
import requests
from bs4 import BeautifulSoup
from confluent_kafka import Producer
import json

# Your NewsAPI key
API_KEY = '7d882785b7414c3ebb4a04caf1eff136'  # Replace with your actual API key

# List of countries to fetch headlines from
countries = ['us', 'gb', 'ca', 'in', 'jp', 'it']

# NewsAPI endpoint for top headlines
url = 'https://newsapi.org/v2/top-headlines'
total_articles = 0 # Function to send data to Kafka topic

def send_to_kafka(topic, data):
    producer = Producer({'bootstrap.servers': 'localhost:9092'})  # Adjust Kafka broker address as needed
    #for entry in data:
    print(data)
    producer.produce(topic, json.dumps(data).encode('utf-8'))
    producer.flush()
    
def fetch_articles_for_country(country):
    params = {
        'country': country,
        'language': 'en',
        'apiKey': API_KEY
    }
    url = "https://newsapi.org/v2/top-headlines"
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        return data['articles']
    else:
        print(f'Error fetching headlines for {country.upper()}:', response.status_code)
        return []

def process_article(article):
    article_id = generate_random_id()  # Replace with actual function
    full_content = scrape_article_content(article['url'])  # Replace with actual function

    article_data = {
        'articleID': article_id,
        'sourceDomain': article.get('source', {}).get('name', 'N/A'),
        'title': article['title'],
        'url': article['url'],
        'content': full_content
    }

    kafka_topic = "LSH_New_8"
    send_to_kafka(kafka_topic, article_data)  # Replace with actual function
    print("Data sent to Kafka:", article_data)
    print("-" * 50)

# Continuously stream data
while True:
    for country in countries:
        #print(f"Headlines from {country.upper()}:")
        #print("-" * 50)

        articles = fetch_articles_for_country(country)
        total_articles += len(articles)
        
        for article in articles:
            process_article(article)
        
        print("\n")
    
    # Delay to avoid overwhelming the NewsAPI server and respect rate limits
    time.sleep(60)
# Out:
# {'articleID': 'fc961bf6eb544b3eb7e212fc6ea77f32', 'sourceDomain': 'The Washington Post', 'title': 'Middle East conflict live updates: Hamas says it views cease-fire talks favorably; Blinken urges group to accept deal - The Washington Post', 'url': 'https://www.washingtonpost.com/world/2024/05/02/israel-hamas-war-news-gaza-palestine/', 'content': 'U.S. Secretary of State Antony Blinken urged Hamas to accept the latest cease-fire and hostage-release agreement proposed by Israel. In a statement, Ismail Haniyeh, chairman of the militant group’s political bureau, said Hamas views the Egypt-hosted negotiations in a “positive spirit” and said that a negotiating delegation would travel to Cairo as soon as possible. 1/7'}
# %3|1714773602.714|FAIL|rdkafka#producer-34| [thrd:mlk-scs-fvfgj4jmq6lr.attlocal.net:9092/0]: mlk-scs-fvfgj4jmq6lr.attlocal.net:9092/0: Connect to ipv6#[2600:1700:65a0:20c0:e5fc:c7b4:42d3:ce7d]:9092 failed: Network is unreachable (after 7226ms in state CONNECT)
# ...

# %%
from bs4 import BeautifulSoup
